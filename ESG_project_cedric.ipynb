# %% [markdown]
# # Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data

# %% [markdown]
# ### Historical data

# %%
df_hist_ESG = pd.read_csv('data/ESG Historic Data.csv', sep=';', encoding='latin-1')
df_hist_ESG.shape
# Out:
# (34672, 276)

# %%
df_hist_ESG.columns
# Out:
# Index(['Vigeo Key', 'ISIN', 'Bloomberg Legal entity identifier (LEI)',
#        'Bloomberg Ticker', 'SEDOL code primary', 'SEDOL 2 code', 'Title',
#        'Zone', 'Country', 'Generic Sector',
#        ...
#        'C&S score sector average', 'CIN score sector average',
#        'CG score sector average', 'HRts score sector average',
#        'HRS Domain rating', 'ENV Domain rating', 'C&S Domain rating',
#        'CIN Domain rating', 'CGV Domain rating', 'HRT Domain rating'],
#       dtype='object', length=276)

# %%
# ESG sub-criteria
global_score = ['ISIN', 'Global score']
global_score = ['ISIN', 'Global score']
ESG_criteria = ['Produced date','ISIN','ESG ENV score', 'ESG SOC score', 'ESG GOV score'] 
ESG_sub_criteria = ['Produced date','ISIN', 'HRS Domain score','ENV score','C&S score', 'CIN score', 'CG score', 'HRts score']
ESG_sub_sub_criteria = ['Produced date','ISIN', 
                        'HR L-score', 'HR I-score', 'HR R-score', 
                        'ENV L-score', 'ENV I-score','ENV R-score', 
                        'C&S L-score', 'C&S I-score', 'C&S R-score', 
                        'CIN score', 'CIN L-score', 'CIN I-score', 'CIN R-score',
                        'CG L-score', 'CG I-score', 'CG R-score', 
                        'HRts R-score', 'HRts I-score', 'HRts R-score']

# %% [markdown]
# ### Financial data

# %%
df_financial_data = pd.read_excel('data/Financial DATA.xlsx')
df_financial_data.shape
# Out:
# (1541, 16)

# %%
usfull_col = ['Ticker', 'Pays/Région', 'Secteur']

# %%
df_financial_data.head(2)
# Out:
#             Titre   Ticker Source   Position  Var pos  % circ  % Net  \
# 0       Apple Inc  AAPL US    ETF  1,259,255       28    0.01   4.53
# 1  Microsoft Corp  MSFT US    ETF    547.454       13    0.01   3.62
#
#      VM actu     Rpt MV  Var VM ac Déposé le Pays/Région      Secteur  \
# 0  181.50MLN  172.74MLN  +4,035.79  03/15/22  Etats-Unis  Technologie
# 1  142.16MLN  137.83MLN  +3,375.77  03/15/22  Etats-Unis  Technologie
#
#                         Sous-secteur       Région Type d'actif
# 0  Matériel tech et semi-conducteurs  Am. du Nord      Actions
# 1           Logiciels et srvces tech  Am. du Nord      Actions

# %% [markdown]
# ### Coresspondance table

# %%
df_corespondance = pd.read_excel('data/Correspondence Table.xlsx')
df_corespondance.shape
# Out:
# (4208, 24)

# %%
df_corespondance = df_corespondance[['ISSUER', 'ISIN','TICKER EQUITY', 'CDS 5 ANS']]

# %%
df_corespondance.isna().sum()
# Out:
# ISSUER           1691
# ISIN             1691
# TICKER EQUITY    2473
# CDS 5 ANS        3033
# dtype: int64

# %%
df_corespondance.dropna(subset=['TICKER EQUITY', 'ISSUER', 'CDS 5 ANS'], inplace = True)

# %%
df_corespondance.shape[0]
# Out:
# 782

# %%
df_corespondance.head(3)
# Out:
#            ISSUER          ISIN   TICKER EQUITY CDS 5 ANS
# 0       Apple Inc  US0378331005  AAPL US Equity  CY179834
# 1  Microsoft Corp  US5949181045  MSFT US Equity  CX399237
# 2  Amazon.com Inc  US0231351067  AMZN US Equity  CY372412

# %%
df_corespondance.isna().sum()
# Out:
# ISSUER           0
# ISIN             0
# TICKER EQUITY    0
# CDS 5 ANS        0
# dtype: int64

# %%
len(list(df_corespondance['TICKER EQUITY'].unique()))
# Out:
# 781

# %%
def substract(a, b):                              
    return "".join(a.rsplit(b))

clean_ticker = []
for i in df_corespondance['TICKER EQUITY']:
    clean_ticker.append(substract(i, 'Equity'))
    
df_corespondance['ticker'] = clean_ticker

# %%
df_corespondance
# Out:
#                         ISSUER          ISIN    TICKER EQUITY CDS 5 ANS  \
# 0                    Apple Inc  US0378331005   AAPL US Equity  CY179834
# 1               Microsoft Corp  US5949181045   MSFT US Equity  CX399237
# 2               Amazon.com Inc  US0231351067   AMZN US Equity  CY372412
# 3                 Alphabet Inc  US02079K3059  GOOGL US Equity  CX410247
# 4                    Tesla Inc  US88160R1014   GOOG US Equity  CY371958
# ...                        ...           ...              ...       ...
# 1728  SLOVAKIA GOVERNMENT BOND  SK4120009762   AFRY SS Equity  CSLVK1U5
# 1730      CHINA GOVT INTL BOND  XS2078532913    ROO LN Equity  CCHIN1U5
# 1731   CIE FINANCEMENT FONCIER  FR0014002X50    IVG IM Equity  CY360464
# 1733   LANDWIRTSCH. RENTENBANK  XS1957349332    AG1 GR Equity  CY416840
# 1734               ING BANK NV  XS1805257265   POLY LN Equity   CING1E5
#
#          ticker
# 0      AAPL US
# 1      MSFT US
# 2      AMZN US
# 3     GOOGL US
# 4      GOOG US
# ...         ...
# 1728   AFRY SS
# 1730    ROO LN
# 1731    IVG IM
# 1733    AG1 GR
# 1734   POLY LN
#
# [782 rows x 5 columns]

# %%
df_corespondance.rename(columns = {'ticker':'TICKER'}, inplace = True)

# %%
#df_corespondance.drop('TICKER', axis = 1, inplace = True)

# %%
df_corespondance.head(5)
# Out:
#            ISSUER          ISIN    TICKER EQUITY CDS 5 ANS     TICKER
# 0       Apple Inc  US0378331005   AAPL US Equity  CY179834   AAPL US
# 1  Microsoft Corp  US5949181045   MSFT US Equity  CX399237   MSFT US
# 2  Amazon.com Inc  US0231351067   AMZN US Equity  CY372412   AMZN US
# 3    Alphabet Inc  US02079K3059  GOOGL US Equity  CX410247  GOOGL US
# 4       Tesla Inc  US88160R1014   GOOG US Equity  CY371958   GOOG US

# %% [markdown]
# ### Equity data

# %%
df_equity = pd.read_csv('Data/MSCI WORLD TT RETURN DIV BRUT.csv', sep=';', encoding='latin-1')

# %%
df_equity.head(3)
# Out:
#         Dates AAPL US Equity MSFT US Equity AMZN US Equity GOOGL US Equity  \
# 0  02/01/2012        -0,0296        -0,2306        -0,4371          0,5448
# 1  03/01/2012         1,5383         3,1009         3,4258          3,0206
# 2  04/01/2012         0,5374         2,3725         -0,849          0,4313
#
#   GOOG US Equity TSLA US Equity NVDA US Equity UNH US Equity FB US Equity  \
# 0            NaN        -0,5917        -0,7874       -0,9769          NaN
# 1            NaN        -1,6807         1,2987        1,5983          NaN
# 2            NaN        -1,3177         1,1396        1,4566          NaN
#
#    ... 3635 JP Equity 4506 JP Equity MLCO US Equity 2412 JP Equity  \
# 0  ...         2,2581        -0,2275         2,7778        -0,9276
# 1  ...         2,2581        -0,2275         3,4304        -0,9276
# 2  ...         0,4732         0,5701        -1,3065              0
#
#   7205 JP Equity WEED CN Equity FUTU US Equity 8439 JP Equity 4927 JP Equity  \
# 0         0,2146       -11,5385            NaN        -0,6148         0,1444
# 1         0,2146       -11,5385            NaN        -0,6148         0,1444
# 2        -0,2141       -11,5385            NaN         3,6426         0,0481
#
#   INPST NA Equity
# 0             NaN
# 1             NaN
# 2             NaN
#
# [3 rows x 1541 columns]

# %%
df_equity.shape
# Out:
# (2662, 1541)

# %%
df_equity_m=df_equity.set_index('Dates')

# %%
df_equity_m=df_equity_m.fillna(method='ffill')

# %%
df_equity_m=df_equity_m.fillna(0)
df_equity_m.head(5)
# Out:
#            AAPL US Equity MSFT US Equity AMZN US Equity GOOGL US Equity  \
# Dates
# 02/01/2012        -0,0296        -0,2306        -0,4371          0,5448
# 03/01/2012         1,5383         3,1009         3,4258          3,0206
# 04/01/2012         0,5374         2,3725         -0,849          0,4313
# 05/01/2012         1,1102         1,0219         0,0563         -1,3871
# 06/01/2012         1,0454         1,5354         2,8152         -1,3642
#
#            GOOG US Equity TSLA US Equity NVDA US Equity UNH US Equity  \
# Dates
# 02/01/2012              0        -0,5917        -0,7874       -0,9769
# 03/01/2012              0        -1,6807         1,2987        1,5983
# 04/01/2012              0        -1,3177         1,1396        1,4566
# 05/01/2012              0        -2,1292         3,5915          0,67
# 06/01/2012              0        -0,7743        -1,1557        0,3613
#
#            FB US Equity JNJ US Equity  ... 3635 JP Equity 4506 JP Equity  \
# Dates                                  ...
# 02/01/2012            0       -0,4554  ...         2,2581        -0,2275
# 03/01/2012            0        0,4575  ...         2,2581        -0,2275
# 04/01/2012            0       -0,6072  ...         0,4732         0,5701
# 05/01/2012            0       -0,1222  ...        -2,1978         1,1338
# 06/01/2012            0       -0,8716  ...         0,9631        -2,4664
#
#            MLCO US Equity 2412 JP Equity 7205 JP Equity WEED CN Equity  \
# Dates
# 02/01/2012         2,7778        -0,9276         0,2146       -11,5385
# 03/01/2012         3,4304        -0,9276         0,2146       -11,5385
# 04/01/2012        -1,3065              0        -0,2141       -11,5385
# 05/01/2012         1,6293         1,1236         0,4292       -11,5385
# 06/01/2012        -4,7094         0,3704        -1,9231       -11,5385
#
#            FUTU US Equity 8439 JP Equity 4927 JP Equity INPST NA Equity
# Dates
# 02/01/2012              0        -0,6148         0,1444               0
# 03/01/2012              0        -0,6148         0,1444               0
# 04/01/2012              0         3,6426         0,0481               0
# 05/01/2012              0        -1,2599         0,2883               0
# 06/01/2012              0        -1,2089          1,677               0
#
# [5 rows x 1540 columns]

# %%
df_equity_m=df_equity_m.apply(lambda x: x.str.replace(',','.'))

# %%
df_equity_m=df_equity_m.astype(float)

# %%
df_equity_m.index = pd.to_datetime(df_equity_m.index)

# %%
print(df_equity_m)
# Out:
#             AAPL US Equity  MSFT US Equity  AMZN US Equity  GOOGL US Equity  \
# Dates
# 2012-02-01         -0.0296         -0.2306         -0.4371           0.5448
# 2012-03-01          1.5383          3.1009          3.4258           3.0206
# 2012-04-01          0.5374          2.3725         -0.8490           0.4313
# 2012-05-01          1.1102          1.0219          0.0563          -1.3871
# 2012-06-01          1.0454          1.5354          2.8152          -1.3642
# ...                    ...             ...             ...              ...
# 2022-09-03          3.4997          4.5858          2.4001           4.9687
# 2022-10-03         -2.7186         -1.0087          5.4125          -0.7424
# 2022-11-03         -2.3909         -1.9328         -0.8807          -1.9323
# 2022-03-14         -2.6562         -1.2961         -2.5229          -3.0180
# 2022-03-15         -2.6562         -1.2961         -2.5229          -3.0180
#
#             GOOG US Equity  TSLA US Equity  NVDA US Equity  UNH US Equity  \
# Dates
# 2012-02-01             NaN         -0.5917         -0.7874        -0.9769
# 2012-03-01             NaN         -1.6807          1.2987         1.5983
# 2012-04-01             NaN         -1.3177          1.1396         1.4566
# 2012-05-01             NaN         -2.1292          3.5915         0.6700
# 2012-06-01             NaN         -0.7743         -1.1557         0.3613
# ...                    ...             ...             ...            ...
# 2022-09-03          5.1757          4.1934          6.9722         2.5578
# 2022-10-03         -0.8845         -2.4064         -1.5469         1.2089
# 2022-11-03         -1.6630         -5.1235         -2.4627        -1.4488
# 2022-03-14         -2.8622         -3.6437         -3.4842         1.0458
# 2022-03-15         -2.8622         -3.6437         -3.4842         1.0458
#
#             FB US Equity  JNJ US Equity  ...  3635 JP Equity  4506 JP Equity  \
# Dates                                    ...
# 2012-02-01           NaN        -0.4554  ...          2.2581         -0.2275
# 2012-03-01           NaN         0.4575  ...          2.2581         -0.2275
# 2012-04-01           NaN        -0.6072  ...          0.4732          0.5701
# 2012-05-01           NaN        -0.1222  ...         -2.1978          1.1338
# 2012-06-01           NaN        -0.8716  ...          0.9631         -2.4664
# ...                  ...            ...  ...             ...             ...
# 2022-09-03        4.3145         0.3793  ...          1.8592         -1.7286
# 2022-10-03       -1.6574         0.1771  ...          2.6076          4.3096
# 2022-11-03       -3.8932        -0.1827  ...         -3.9390         -1.1804
# 2022-03-14       -0.5224         1.3818  ...          3.1746          1.3652
# 2022-03-15       -0.5224         1.3818  ...          0.7692          1.6835
#
#             MLCO US Equity  2412 JP Equity  7205 JP Equity  WEED CN Equity  \
# Dates
# 2012-02-01          2.7778         -0.9276          0.2146        -11.5385
# 2012-03-01          3.4304         -0.9276          0.2146        -11.5385
# 2012-04-01         -1.3065          0.0000         -0.2141        -11.5385
# 2012-05-01          1.6293          1.1236          0.4292        -11.5385
# 2012-06-01         -4.7094          0.3704         -1.9231        -11.5385
# ...                    ...             ...             ...             ...
# 2022-09-03          7.2983          0.6873         -1.3761          5.9406
# 2022-10-03         -5.1313          5.1621          4.6512         -4.4393
# 2022-11-03        -15.3459         -3.2860         -2.2222         -5.3790
# 2022-03-14         -9.5097         -0.4195          4.2424         -5.8140
# 2022-03-15         -9.5097          0.0000          2.4709         -5.8140
#
#             FUTU US Equity  8439 JP Equity  4927 JP Equity  INPST NA Equity
# Dates
# 2012-02-01             NaN         -0.6148          0.1444              NaN
# 2012-03-01             NaN         -0.6148          0.1444              NaN
# 2012-04-01             NaN          3.6426          0.0481              NaN
# 2012-05-01             NaN         -1.2599          0.2883              NaN
# 2012-06-01             NaN         -1.2089          1.6770              NaN
# ...                    ...             ...             ...              ...
# 2022-09-03          5.0110         -0.4938          0.5614           9.8865
# 2022-10-03        -15.8664          6.5757          4.4045          -1.9049
# 2022-11-03         -8.7558         -4.1909         -2.0796           2.7537
# 2022-03-14         -5.2448          1.8226         -4.9150          -1.1424
# 2022-03-15         -5.2448          4.0573          0.6382          -3.2941
#
# [2662 rows x 1540 columns]

# %%
df_equity_m = df_equity_m.resample(rule='A').mean()

# %%
y=df_equity_m.stack()
y_df=pd.DataFrame(y)
y_df=y_df.reset_index(inplace=False)
y_df=y_df.rename(columns={"level_1": "TICKER"})

# %%
y_df.rename(columns = {0:'Return'}, inplace = True)

# %%
y_df.head(5)
# Out:
#        Dates           TICKER    Return
# 0 2012-12-31   AAPL US Equity  0.125975
# 1 2012-12-31   MSFT US Equity  0.051546
# 2 2012-12-31   AMZN US Equity  0.232471
# 3 2012-12-31  GOOGL US Equity  0.031781
# 4 2012-12-31   TSLA US Equity  0.037801

# %%
def substract(a, b):                              
    return "".join(a.rsplit(b))

clean_columns = []
for i in df_equity.columns:
    clean_columns.append(substract(i, 'Equity'))
    
df_equity.set_axis(clean_columns, axis=1, inplace = True)
df_equity.head(5)

# %% [markdown]
# ## Merge dataset
# - Merge the data frame
#     - Return of the stocks and correspondance table data : key = TICKER
#     - ESG historical data and correspondance table : key = ISIN
#     - correspondance table (key = ISSUER) and financial data (key = Titre)
#     - Merge all the 3 dataframe

# %% [markdown]
# ### MERGE 1 - RETURN and CORRESPONDANCE

# %%
df_corespondance.rename(columns = {'TICKER EQUITY' : 'TICKER'}, inplace = True)
RETURN_CORRESP=pd.merge(df_corespondance, y_df, on='TICKER', how='inner')

# %%
RETURN_CORRESP.shape[0]
# Out:
# 7756

# %%
RETURN_CORRESP.head(5)
# Out:
#       ISSUER          ISIN          TICKER CDS 5 ANS      Dates    Return
# 0  Apple Inc  US0378331005  AAPL US Equity  CY179834 2012-12-31  0.125975
# 1  Apple Inc  US0378331005  AAPL US Equity  CY179834 2013-12-31  0.055808
# 2  Apple Inc  US0378331005  AAPL US Equity  CY179834 2014-12-31  0.149098
# 3  Apple Inc  US0378331005  AAPL US Equity  CY179834 2015-12-31 -0.008916
# 4  Apple Inc  US0378331005  AAPL US Equity  CY179834 2016-12-31  0.041784

# %%
len(list(RETURN_CORRESP['TICKER'].unique()))
# Out:
# 738

# %% [markdown]
# ### Merge 2 : RETURN_CORRESP and ESG HIST DATA

# %%
ESG_sub_criteria = ['Produced date','ISIN', ']
ESG_SCORE = df_hist_ESG[ESG_sub_criteria]

# %%
DATA_ESG_SCORE_RETURN =pd.merge(ESG_SCORE, RETURN_CORRESP, on='ISIN', how='inner')

# %%
DATA_ESG_SCORE_RETURN
# Out:
#       Produced date          ISIN  HRS Domain score  ENV score  C&S score  \
# 0        01/03/2007  GB00B1YW4409                20         47         45
# 1        01/03/2007  GB00B1YW4409                20         47         45
# 2        01/03/2007  GB00B1YW4409                20         47         45
# 3        01/03/2007  GB00B1YW4409                20         47         45
# 4        01/03/2007  GB00B1YW4409                20         47         45
# ...             ...           ...               ...        ...        ...
# 97977    01/03/2016  CH0011075394                29         48         42
# 97978    01/03/2016  CH0011075394                29         48         42
# 97979    01/03/2016  CH0011075394                29         48         42
# 97980    01/03/2016  CH0011075394                29         48         42
# 97981    01/03/2016  CH0011075394                29         48         42
#
#        CIN score  CG score  HRts score                     ISSUER  \
# 0             50        68          21               3i Group PLC
# 1             50        68          21               3i Group PLC
# 2             50        68          21               3i Group PLC
# 3             50        68          21               3i Group PLC
# 4             50        68          21               3i Group PLC
# ...          ...       ...         ...                        ...
# 97977         30        51          50  Zurich Insurance Group AG
# 97978         30        51          50  Zurich Insurance Group AG
# 97979         30        51          50  Zurich Insurance Group AG
# 97980         30        51          50  Zurich Insurance Group AG
# 97981         30        51          50  Zurich Insurance Group AG
#
#                TICKER CDS 5 ANS      Dates    Return
# 0       FMC US Equity  CT355208 2012-12-31  0.148033
# 1       FMC US Equity  CT355208 2013-12-31  0.127265
# 2       FMC US Equity  CT355208 2014-12-31 -0.092007
# 3       FMC US Equity  CT355208 2015-12-31 -0.132503
# 4       FMC US Equity  CT355208 2016-12-31  0.178651
# ...               ...       ...        ...       ...
# 97977  LRCX US Equity  CZURN1E5 2018-12-31 -0.111789
# 97978  LRCX US Equity  CZURN1E5 2019-12-31  0.336643
# 97979  LRCX US Equity  CZURN1E5 2020-12-31  0.260276
# 97980  LRCX US Equity  CZURN1E5 2021-12-31  0.230128
# 97981  LRCX US Equity  CZURN1E5 2022-12-31 -0.733779
#
# [97982 rows x 13 columns]

# %% [markdown]
# ### Merge 3 : correspondance table (key = ISSUER) and financial data (key = Titre)

# %%
usfull_cols = ['Titre', 'VM actu', 'Pays/Région', 'Secteur']
FINANCIAL_CORRESP = pd.merge(df_corespondance[['ISIN', 'ISSUER']], df_financial_data[usfull_cols], 
                             left_on='ISSUER', right_on='Titre')
FINANCIAL_CORRESP.shape
# Out:
# (596, 6)

# %%
FINANCIAL_CORRESP.head(5)
# Out:
#            ISIN                  ISSUER                   Titre    VM actu  \
# 0  US0378331005               Apple Inc               Apple Inc  181.50MLN
# 1  US5949181045          Microsoft Corp          Microsoft Corp  142.16MLN
# 2  US0231351067          Amazon.com Inc          Amazon.com Inc   93.53MLN
# 3  US88160R1014               Tesla Inc               Tesla Inc   49.94MLN
# 4  US91324P1021  UnitedHealth Group Inc  UnitedHealth Group Inc   32.30MLN
#
#   Pays/Région                Secteur
# 0  Etats-Unis            Technologie
# 1  Etats-Unis            Technologie
# 2  Etats-Unis  Conso discrétionnaire
# 3  Etats-Unis  Conso discrétionnaire
# 4  Etats-Unis                  Santé

# %% [markdown]
# ### Merge4 : DataFrame with all the parameters

# %%
DATA_FINAL = pd.merge(FINANCIAL_CORRESP, DATA_ESG_SCORE_RETURN, on='ISIN', how='right')

# %%
DATA_FINAL.shape[0]
# Out:
# 97982

# %%
DATA_FINAL.head(2)
# Out:
#            ISIN      ISSUER_x         Titre  VM actu  Pays/Région  \
# 0  GB00B1YW4409  3i Group PLC  3i Group PLC  1.10MLN  Royaume-Uni
# 1  GB00B1YW4409  3i Group PLC  3i Group PLC  1.10MLN  Royaume-Uni
#
#        Secteur Produced date  HRS Domain score  ENV score  C&S score  \
# 0  Financières    01/03/2007                20         47         45
# 1  Financières    01/03/2007                20         47         45
#
#    CIN score  CG score  HRts score      ISSUER_y         TICKER CDS 5 ANS  \
# 0         50        68          21  3i Group PLC  FMC US Equity  CT355208
# 1         50        68          21  3i Group PLC  FMC US Equity  CT355208
#
#        Dates    Return
# 0 2012-12-31  0.148033
# 1 2013-12-31  0.127265

# %% [markdown]
# # Machine Learning to predict RETURN using ESG CRITERIA

# %%
from sklearn.model_selection import train_test_split

# %%
def split_df(df, target = 'Return'):
    """
    Inputs : Dataframe and the name of the target column set by default to Return
    Output : dictionary of 4 DataFrames with keys : x_train,y_train,  x_test, y_test
    
    """
    
    # Create features and target
    x = df.drop(target, axis = 1)
    y = df[[target]].values

    # Echantillon de test (20%) et train (80%)
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2 , random_state = 100, shuffle=False)
    
    return {'x_train' : x_train, 'x_test' : x_test, 'y_train' : y_train, 'y_test' : y_test}

# %%
DATA_ESG_SCORE_RETURN.columns
# Out:
# Index(['Produced date', 'ISIN', 'HRS Domain score', 'ENV score', 'C&S score',
#        'CIN score', 'CG score', 'HRts score', 'ISSUER', 'TICKER', 'CDS 5 ANS',
#        'Dates', 'Return'],
#       dtype='object')

# %% [markdown]
# #### Model with ESG criteria only

# %%
Input_columns = ['HRS Domain score','ENV score','C&S score', 'CIN score', 'CG score', 'HRts score', 'Return']
DATA = DATA_ESG_SCORE_RETURN[Input_columns]

# %%
# Training set
x_train = split_df(DATA)['x_train']
y_train = split_df(DATA)['y_train']

# %%
# Test set
x_test = split_df(DATA)['x_test']
y_test = split_df(DATA)['y_test']

# %%
reg = LinearRegression().fit(x_train, y_train)

# %%
#reg.coef_
reg.intercept_
coef = reg.coef_

# %%
coef
# Out:
# array([[-1.30183162e-04, -1.22327885e-04,  1.79937501e-04,
#          1.89865925e-04,  4.93553742e-05, -1.34209867e-04]])

# %%
y_pred = reg.predict(x_test)

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 0.03683349050240753

# %%
model = sm.OLS(y_train,x_train)
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.067
# Model:                            OLS   Adj. R-squared (uncentered):              0.067
# Method:                 Least Squares   F-statistic:                              944.7
# Date:                Fri, 22 Apr 2022   Prob (F-statistic):                        0.00
# Time:                        22:54:44   Log-Likelihood:                          10472.
# No. Observations:               78385   AIC:                                 -2.093e+04
# Df Residuals:                   78379   BIC:                                 -2.088e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# HRS Domain score    -0.0005   7.72e-05     -5.929      0.000      -0.001      -0.000
# ENV score         -3.63e-05   6.43e-05     -0.565      0.572      -0.000    8.97e-05
# C&S score            0.0008   8.41e-05      9.048      0.000       0.001       0.001
# CIN score            0.0001   6.32e-05      2.024      0.043    4.04e-06       0.000
# CG score             0.0005   5.17e-05      8.998      0.000       0.000       0.001
# HRts score           0.0003   8.48e-05      3.419      0.001       0.000       0.000
# ==============================================================================
# Omnibus:                   102648.245   Durbin-Watson:                   2.156
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        177448675.438
# Skew:                           6.558   Prob(JB):                         0.00
# Kurtosis:                     235.722   Cond. No.                         14.3
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Model with ESG criteria and characteristics of the company

# %%
DATA_FINAL.columns
# Out:
# Index(['ISIN', 'ISSUER_x', 'Titre', 'VM actu', 'Pays/Région', 'Secteur',
#        'Produced date', 'HRS Domain score', 'ENV score', 'C&S score',
#        'CIN score', 'CG score', 'HRts score', 'ISSUER_y', 'TICKER',
#        'CDS 5 ANS', 'Dates', 'Return'],
#       dtype='object')

# %%
Input_columns = ['HRS Domain score','ENV score','C&S score', 'CIN score', 'CG score', 'HRts score','VM actu',
                 'Pays/Région', 'Secteur', 'Return']

# %% [markdown]
# # FIN

# %% [markdown]
# ## Merge dataset
# - Merge the data frame
#     - ESG historical data and correspondance table : key = ISIN
#     - coreespondance table (key = ISSUER) and financial data (key = Titre)
#     - Merge all the 3 dataframe

# %%
global_score = ['ISIN', 'Global score']
global_score = ['ISIN', 'Global score']
ESG_criteria = ['Produced date','ISIN','ESG ENV score', 'ESG SOC score', 'ESG GOV score'] 
ESG_sub_criteria = ['Produced date','ISIN', 'HRS Domain score','ENV score','C&S score', 'CIN score', 'CG score', 'HRts score']
ESG_sub_sub_criteria = ['Produced date','ISIN', 
                        'HR L-score', 'HR I-score', 'HR R-score', 
                        'ENV L-score', 'ENV I-score','ENV R-score', 
                        'C&S L-score', 'C&S I-score', 'C&S R-score', 
                        'CIN score', 'CIN L-score', 'CIN I-score', 'CIN R-score',
                        'CG L-score', 'CG I-score', 'CG R-score', 
                        'HRts R-score', 'HRts I-score', 'HRts R-score']

# %%
df_hist_ESG[ESG_sub_criteria].head(3)
# Out:
#   Produced date          ISIN  HRS Domain score  ENV score  C&S score  \
# 0    01/09/2021  DE0005545503                32         30         34
# 1    01/11/2020  DE0005545503                13         17         29
# 2    01/09/2019  DE0005545503                13         20         29
#
#    CIN score  CG score  HRts score
# 0         15        38          47
# 1          9        29          42
# 2          9        25          45

# %%
df_hist_ESG[ESG_criteria].head(3)
# Out:
#   Produced date          ISIN  ESG ENV score  ESG SOC score  ESG GOV score
# 0    01/09/2021  DE0005545503           30.0           34.0           37.0
# 1    01/11/2020  DE0005545503           19.0           24.0           28.0
# 2    01/09/2019  DE0005545503           22.0           25.0           26.0

# %% [markdown]
# ### Merge ESG hist data and Correspondance table

# %%
#Merging
ESG_CORRESP = pd.merge(df_hist_ESG[ESG_sub_criteria], df_corespondance, how='inner', on='ISIN')
ESG_CORRESP.shape
# Out:
# (9522, 12)

# %%
ESG_CORRESP = ESG_CORRESP.rename(columns={"Produced date": "Dates"})

# %%
ESG_CORRESP
# Out:
#            Dates          ISIN  HRS Domain score  ENV score  C&S score  \
# 0     01/03/2007  GB00B1YW4409                20         47         45
# 1     01/03/2005  GB00B1YW4409                44         36         40
# 2     01/01/2020  GB00B1YW4409                40         50         54
# 3     01/03/2018  GB00B1YW4409                36         46         59
# 4     01/03/2016  GB00B1YW4409                35         44         49
# ...          ...           ...               ...        ...        ...
# 9517  01/01/2020  CH0011075394                34         55         39
# 9518  01/07/2019  CH0011075394                34         55         40
# 9519  01/03/2018  CH0011075394                34         51         40
# 9520  03/07/2021  CH0011075394                37         59         34
# 9521  01/03/2016  CH0011075394                29         48         42
#
#       CIN score  CG score  HRts score                     ISSUER  \
# 0            50        68          21               3i Group PLC
# 1            63        65          35               3i Group PLC
# 2            42        71          59               3i Group PLC
# 3            40        66          58               3i Group PLC
# 4            24        62          52               3i Group PLC
# ...         ...       ...         ...                        ...
# 9517         28        57          53  Zurich Insurance Group AG
# 9518         28        57          53  Zurich Insurance Group AG
# 9519         28        57          53  Zurich Insurance Group AG
# 9520         31        69          54  Zurich Insurance Group AG
# 9521         30        51          50  Zurich Insurance Group AG
#
#        TICKER EQUITY CDS 5 ANS    TICKER
# 0      FMC US Equity  CT355208   FMC US
# 1      FMC US Equity  CT355208   FMC US
# 2      FMC US Equity  CT355208   FMC US
# 3      FMC US Equity  CT355208   FMC US
# 4      FMC US Equity  CT355208   FMC US
# ...              ...       ...       ...
# 9517  LRCX US Equity  CZURN1E5  LRCX US
# 9518  LRCX US Equity  CZURN1E5  LRCX US
# 9519  LRCX US Equity  CZURN1E5  LRCX US
# 9520  LRCX US Equity  CZURN1E5  LRCX US
# 9521  LRCX US Equity  CZURN1E5  LRCX US
#
# [9522 rows x 12 columns]

# %%
df_corespondance.shape
# Out:
# (782, 5)

# %%
ESG_CORRESP.groupby('TICKER')['Dates'].count()
# Out:
# TICKER
# 11 HK       17
# 1299 HK     29
# 1801 JP      5
# 1812 JP     12
# 1925 JP      9
#             ..
# ZEN US       7
# ZI US        7
# ZS US        9
# ZTS US      15
# ZURN SW      8
# Name: Dates, Length: 753, dtype: int64

# %%
y_df

# %%
ESG

# %%
df_corespondance = pd.read_excel('data/Correspondence Table.xlsx')
df_corespondance.shape
# Out:
# (4208, 24)

# %%
df_corespondance
# Out:
#               ISSUER          ISIN              TICKER CDS 5 ANS  Unnamed: 4  \
# 0          Apple Inc  US0378331005      AAPL EU Equity  CY179834         NaN
# 1     Microsoft Corp  US5949181045   MSFTUSD EU Equity  CX399237         NaN
# 2     Amazon.com Inc  US0231351067   AMZNUSD EU Equity  CY372412         NaN
# 3       Alphabet Inc  US02079K3059  GOOG1USD EU Equity  CX410247         NaN
# 4          Tesla Inc  US88160R1014   TSLAUSD EU Equity  CY371958         NaN
# ...              ...           ...                 ...       ...         ...
# 4203             NaN           NaN                 NaN       NaN         NaN
# 4204             NaN           NaN                 NaN       NaN         NaN
# 4205             NaN           NaN                 NaN       NaN         NaN
# 4206             NaN           NaN                 NaN       NaN         NaN
# 4207             NaN           NaN                 NaN       NaN         NaN
#
#       Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8    TICKER EQUITY  ...  \
# 0            NaN         NaN         NaN         NaN   AAPL US Equity  ...
# 1            NaN         NaN         NaN         NaN   MSFT US Equity  ...
# 2            NaN         NaN         NaN         NaN   AMZN US Equity  ...
# 3            NaN         NaN         NaN         NaN  GOOGL US Equity  ...
# 4            NaN         NaN         NaN         NaN   GOOG US Equity  ...
# ...          ...         ...         ...         ...              ...  ...
# 4203         NaN         NaN         NaN         NaN              NaN  ...
# 4204         NaN         NaN         NaN         NaN              NaN  ...
# 4205         NaN         NaN         NaN         NaN              NaN  ...
# 4206         NaN         NaN         NaN         NaN              NaN  ...
# 4207         NaN         NaN         NaN         NaN              NaN  ...
#
#      Unnamed: 14        TICKER BOND     ID ISIN.1                ISSUER.2  \
# 0            NaN  EJ346891     Corp  FR0011317783        FRANCE (GOVT OF)
# 1            NaN  EK243274     Corp  FR0011883966        FRANCE (GOVT OF)
# 2            NaN  UV994928     Corp  FR0012993103        FRANCE (GOVT OF)
# 3            NaN  EH878672     Corp  FR0010773192        FRANCE (GOVT OF)
# 4            NaN  GG738427     Corp  FR0000571218        FRANCE (GOVT OF)
# ...          ...                ...           ...                     ...
# 4203         NaN                NaN  XS2247623643              GETLINK SE
# 4204         NaN                NaN  XS2332306344                REXEL SA
# 4205         NaN                NaN  XS2351382473            DERICHEBOURG
# 4206         NaN                NaN  XS2399981435  SECHE ENVIRONNEMENT SA
# 4207         NaN                NaN  US91282CDY49             US TREASURY
#
#       Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21    ISSUER EQUITY & BOND  \
# 0             NaN         NaN         NaN         NaN               APPLE INC
# 1             NaN         NaN         NaN         NaN          MICROSOFT CORP
# 2             NaN         NaN         NaN         NaN       JOHNSON & JOHNSON
# 3             NaN         NaN         NaN         NaN  BERKSHIRE HATHAWAY INC
# 4             NaN         NaN         NaN         NaN     JPMORGAN CHASE & CO
# ...           ...         ...         ...         ...                     ...
# 4203          NaN         NaN         NaN         NaN                     NaN
# 4204          NaN         NaN         NaN         NaN                     NaN
# 4205          NaN         NaN         NaN         NaN                     NaN
# 4206          NaN         NaN         NaN         NaN                     NaN
# 4207          NaN         NaN         NaN         NaN                     NaN
#
#        ISIN EQUITY
# 0     US0378331005
# 1     US5949181045
# 2     US4781601046
# 3     US0846707026
# 4     US46625H1005
# ...            ...
# 4203           NaN
# 4204           NaN
# 4205           NaN
# 4206           NaN
# 4207           NaN
#
# [4208 rows x 24 columns]

# %% [markdown]
# ### Merge financial data and correspondance table

# %%
usfull_cols = ['Titre', 'VM actu', 'Pays/Région', 'Secteur']

# %%
usfull_cols = ['Titre', 'VM actu', 'Pays/Région', 'Secteur']
FINANCIAL_CORRESP = pd.merge(df_corespondance, df_financial_data, left_on='ISSUER', right_on='Titre')
FINANCIAL_CORRESP.shape
# Out:
# (596, 21)

# %%
FINANCIAL_CORRESP.head(3)
# Out:
#            ISSUER          ISIN   TICKER EQUITY CDS 5 ANS    TICKER  \
# 0       Apple Inc  US0378331005  AAPL US Equity  CY179834  AAPL US
# 1  Microsoft Corp  US5949181045  MSFT US Equity  CX399237  MSFT US
# 2  Amazon.com Inc  US0231351067  AMZN US Equity  CY372412  AMZN US
#
#             Titre   Ticker Source   Position  Var pos  ...  % Net    VM actu  \
# 0       Apple Inc  AAPL US    ETF  1,259,255       28  ...   4.53  181.50MLN
# 1  Microsoft Corp  MSFT US    ETF    547.454       13  ...   3.62  142.16MLN
# 2  Amazon.com Inc  AMZN US    ETF     35.033        1  ...   2.38   93.53MLN
#
#       Rpt MV  Var VM ac Déposé le Pays/Région                Secteur  \
# 0  172.74MLN  +4,035.79  03/15/22  Etats-Unis            Technologie
# 1  137.83MLN  +3,375.77  03/15/22  Etats-Unis            Technologie
# 2   90.52MLN  +2,669.89  03/15/22  Etats-Unis  Conso discrétionnaire
#
#                         Sous-secteur       Région Type d'actif
# 0  Matériel tech et semi-conducteurs  Am. du Nord      Actions
# 1           Logiciels et srvces tech  Am. du Nord      Actions
# 2     Détail et gros - Conso discrét  Am. du Nord      Actions
#
# [3 rows x 21 columns]

# %% [markdown]
# ### Merge ESG CORRESP and FINANCIAL CORRESP

# %%
ESG_FINANCIAL_CORRESP = pd.merge(ESG_CORRESP, FINANCIAL_CORRESP, how='left', on='ISIN')
ESG_FINANCIAL_CORRESP.shape
# Out:
# (9522, 32)

# %%
ESG_FINANCIAL_CORRESP.columns
# Out:
# Index(['Dates', 'ISIN', 'HRS Domain score', 'ENV score', 'C&S score',
#        'CIN score', 'CG score', 'HRts score', 'ISSUER_x', 'CDS 5 ANS_x',
#        'TICKER_x', 'ISSUER_y', 'CDS 5 ANS_y', 'TICKER_y', 'Titre', 'Ticker',
#        'Source', 'Position', 'Var pos', '% circ', '% Net', 'VM actu', 'Rpt MV',
#        'Var VM ac', 'Déposé le', 'Pays/Région', 'Secteur', 'Sous-secteur',
#        'Région', 'Type d'actif'],
#       dtype='object')

# %% [markdown]
# ###  Merge ESG_FINANCIAL_CORRESP  and data with RETURN

# %%
ESG_FINANCIAL_CORRESP.rename(columns = {'TICKER EQUITY_x':'TICKER'}, inplace = True)

# %%
ESG_FINANCIAL_CORRESP.columns
# Out:
# Index(['Dates', 'ISIN', 'HRS Domain score', 'ENV score', 'C&S score',
#        'CIN score', 'CG score', 'HRts score', 'ISSUER_x', 'TICKER EQUITY_x',
#        'CDS 5 ANS_x', 'TICKER_x', 'ISSUER_y', 'TICKER EQUITY_y', 'CDS 5 ANS_y',
#        'TICKER_y', 'Titre', 'Ticker', 'Source', 'Position', 'Var pos',
#        '% circ', '% Net', 'VM actu', 'Rpt MV', 'Var VM ac', 'Déposé le',
#        'Pays/Région', 'Secteur', 'Sous-secteur', 'Région', 'Type d'actif'],
#       dtype='object')

# %%
ESG_FINANCIAL_CORRESP['Dates'] = pd.to_datetime(ESG_FINANCIAL_CORRESP['Dates'])

# %%
FINAL_DATA = pd.merge(ESG_FINANCIAL_CORRESP, y_df, on ='TICKER', how ='inner')

# %%
FINAL_DATA
# Out:
# Empty DataFrame
# Columns: [Dates_x, ISIN, HRS Domain score, ENV score, C&S score, CIN score, CG score, HRts score, ISSUER_x, TICKER, CDS 5 ANS_x, TICKER_x, ISSUER_y, TICKER EQUITY_y, CDS 5 ANS_y, TICKER_y, Titre, Ticker, Source, Position, Var pos, % circ, % Net, VM actu, Rpt MV, Var VM ac, Déposé le, Pays/Région, Secteur, Sous-secteur, Région, Type d'actif, Dates_y, Return]
# Index: []
#
# [0 rows x 34 columns]

# %%
df_hist_ESG
# Out:
#           Vigeo Key          ISIN Bloomberg Legal entity identifier (LEI)  \
# 0      DE0005545503  DE0005545503                    5299003VKVDCUPSS5X23
# 1      DE0005545503  DE0005545503                    5299003VKVDCUPSS5X23
# 2      DE0005545503  DE0005545503                    5299003VKVDCUPSS5X23
# 3      DE0005545503  DE0005545503                    5299003VKVDCUPSS5X23
# 4       KVE00000509  US88025U1097                    5493003Z6741WNLG7H43
# ...             ...           ...                                     ...
# 34667  XS0520578096  XS0520578096                    529900UUANUJ60MNMX97
# 34668  XS0520578096  XS0520578096                    529900UUANUJ60MNMX97
# 34669  XS0520578096  XS0520578096                    529900UUANUJ60MNMX97
# 34670  AT0000APOST4  AT0000APOST4                    529900MVUWACNUTK8467
# 34671  AT0000APOST4  AT0000APOST4                    529900MVUWACNUTK8467
#
#       Bloomberg Ticker SEDOL code primary SEDOL 2 code  \
# 0                  1U1            5734672          NaN
# 1                  1U1            5734672          NaN
# 2                  1U1            5734672          NaN
# 3                  1U1            5734672          NaN
# 4                  TXG            BKS3RS7          NaN
# ...                ...                ...          ...
# 34667              NaN                NaN          NaN
# 34668              NaN                NaN          NaN
# 34669              NaN                NaN          NaN
# 34670             POST            B1577G7          NaN
# 34671             POST            B1577G7          NaN
#
#                          Title Zone                   Country  \
# 0                       1&1 AG  EUR                   Germany
# 1                1&1 Drillisch  EUR                   Germany
# 2                1&1 Drillisch  EUR                   Germany
# 3                1&1 Drillisch  EUR                   Germany
# 4           10X Genomics, Inc.  NAM  United States of America
# ...                        ...  ...                       ...
# 34667     ÖBB-Infrastruktur AG  EUR                   Austria
# 34668     ÖBB-Infrastruktur AG  EUR                   Austria
# 34669     ÖBB-Infrastruktur AG  EUR                   Austria
# 34670  Österreichische Post AG  EUR                   Austria
# 34671  Österreichische Post AG  EUR                   Austria
#
#                          Generic Sector  ... C&S score sector average  \
# 0                    Telecommunications  ...                       38
# 1                    Telecommunications  ...                       36
# 2                    Telecommunications  ...                       36
# 3                    Telecommunications  ...                       15
# 4      Health Care Equipment & Services  ...                       33
# ...                                 ...  ...                      ...
# 34667             Transport & Logistics  ...                       32
# 34668             Transport & Logistics  ...                       34
# 34669             Transport & Logistics  ...                       32
# 34670             Transport & Logistics  ...                       34
# 34671             Transport & Logistics  ...                       32
#
#       CIN score sector average CG score sector average  \
# 0                           33                      50
# 1                           31                      49
# 2                           32                      47
# 3                            9                      28
# 4                           29                      40
# ...                        ...                     ...
# 34667                       31                      41
# 34668                       30                      45
# 34669                       31                      41
# 34670                       30                      45
# 34671                       31                      41
#
#        HRts score sector average  HRS Domain rating  ENV Domain rating  \
# 0                             51                  =                  -
# 1                             50                  -                  -
# 2                             49                 --                  -
# 3                             21                  -                  -
# 4                             33                  -                  -
# ...                          ...                ...                ...
# 34667                         37                  -                  -
# 34668                         39                  -                  -
# 34669                         37                  -                  -
# 34670                         39                  =                  =
# 34671                         37                  -                  -
#
#        C&S Domain rating  CIN Domain rating  CGV Domain rating  \
# 0                      =                  -                  -
# 1                      -                  -                  -
# 2                      -                 --                  -
# 3                      -                 --                  -
# 4                      -                  -                  =
# ...                  ...                ...                ...
# 34667                 --                  -                 --
# 34668                  -                  -                 --
# 34669                  -                  -                 --
# 34670                  -                  =                  +
# 34671                  -                  =                  +
#
#        HRT Domain rating
# 0                      =
# 1                      -
# 2                      =
# 3                      -
# 4                      -
# ...                  ...
# 34667                  -
# 34668                  -
# 34669                  -
# 34670                  =
# 34671                  -
#
# [34672 rows x 276 columns]

# %% [markdown]
# Regression

# %%
x

# %%
import statsmodels.api as sm
import numpy as np

model = sm.OLS(Y,X)
results = model.fit()

# %% [markdown]
# # Step 1: critical analysis of data

# %% [markdown]
# - Statistical quality (homogeneity of methods,particularly management methods, volume, representativeness, traceability)
# - Possible consequences of data quality on the results of the studies
# - Very different situation: little data, from several information systems, with missing data, requiring a lot or reprocessing before being exploited. Sometimes no "relevant" data will be available
# - Checked that the data used meet the following 3 criteria: Relevance, Completeness, Accuracy
# - ensure that the data used does not have a significant impact on the calculations or the results obtained

# %% [markdown]
# # Step 2: ESG rating criteria classification
# link between sustainability and trend in world prices & CDS
# - Define which ESG sub-criteria have the strongest financial impact on a company and vice versa
# - Can ESG data be used to forecast prices or CDS
